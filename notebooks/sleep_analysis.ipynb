# %%
# ===============================
# STUDENT SLEEP ANALYSIS NOTEBOOK
# ===============================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

print("Libraries Loaded Successfully ✅")
# Out:
# Libraries Loaded Successfully ✅

# %%
# Load dataset (go one level up from notebooks → data folder)
df = pd.read_csv("../data/student_sleep.csv")

print("Dataset Loaded Successfully ✅")
df.head()
# Out:
# Dataset Loaded Successfully ✅
#    Sleep Hours  GPA  Study Hours  Stress Level
# 0            5  2.5            2             8
# 1            6  3.0            3             7
# 2            7  3.4            4             5
# 3            8  3.8            5             4
# 4            4  2.2            1             9

# %%
# Convert column names to lowercase and replace spaces
df.columns = df.columns.str.lower().str.replace(" ", "_")

print("Updated Columns:")
print(df.columns)

df.head()
# Out:
# Updated Columns:
# Index(['sleep_hours', 'gpa', 'study_hours', 'stress_level'], dtype='str')
#    sleep_hours  gpa  study_hours  stress_level
# 0            5  2.5            2             8
# 1            6  3.0            3             7
# 2            7  3.4            4             5
# 3            8  3.8            5             4
# 4            4  2.2            1             9

# %%
print("Dataset Information:\n")
df.info()
# Out:
# Dataset Information:
#
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sleep_hours   20 non-null     int64
#  1   gpa           20 non-null     float64
#  2   study_hours   20 non-null     int64
#  3   stress_level  20 non-null     int64
# dtypes: float64(1), int64(3)
# memory usage: 772.0 bytes

# %%
print("Missing Values:\n")
df.isnull().sum()
# Out:
# Missing Values:
# sleep_hours     0
# gpa             0
# study_hours     0
# stress_level    0
# dtype: int64

# %%
print("----- BASIC STATISTICS -----\n")

print("Average Sleep Hours:", round(df["sleep_hours"].mean(), 2))
print("Average GPA:", round(df["gpa"].mean(), 2))
print("Average Study Hours:", round(df["study_hours"].mean(), 2))
print("Average Stress Level:", round(df["stress_level"].mean(), 2))

print("\nMinimum Sleep Hours:", df["sleep_hours"].min())
print("Maximum Sleep Hours:", df["sleep_hours"].max())
# Out:
# ----- BASIC STATISTICS -----
#
# Average Sleep Hours: 6.35
# Average GPA: 3.18
# Average Study Hours: 3.4
# Average Stress Level: 5.9
#
# Minimum Sleep Hours: 4
# Maximum Sleep Hours: 9

# %%
df.describe()
# Out:
#        sleep_hours        gpa  study_hours  stress_level
# count    20.000000  20.000000    20.000000     20.000000
# mean      6.350000   3.180000     3.400000      5.900000
# std       1.424411   0.556871     1.500877      1.860956
# min       4.000000   2.100000     1.000000      3.000000
# 25%       5.000000   2.775000     2.000000      4.750000
# 50%       6.000000   3.250000     3.000000      6.000000
# 75%       7.250000   3.625000     4.250000      7.250000
# max       9.000000   3.900000     6.000000      9.000000

# %%
correlation = df.corr()

print("Correlation Matrix:\n")
correlation
# Out:
# Correlation Matrix:
#               sleep_hours       gpa  study_hours  stress_level
# sleep_hours      1.000000  0.971399     0.989674     -0.978863
# gpa              0.971399  1.000000     0.967248     -0.982228
# study_hours      0.989674  0.967248     1.000000     -0.983639
# stress_level    -0.978863 -0.982228    -0.983639      1.000000

# %%
plt.figure(figsize=(6,4))
sns.heatmap(correlation, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x="sleep_hours", y="gpa", data=df)
plt.title("Sleep Hours vs GPA")
plt.xlabel("Sleep Hours")
plt.ylabel("GPA")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x="sleep_hours", y="stress_level", data=df)
plt.title("Sleep Hours vs Stress Level")
plt.xlabel("Sleep Hours")
plt.ylabel("Stress Level")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x="study_hours", y="gpa", data=df)
plt.title("Study Hours vs GPA")
plt.xlabel("Study Hours")
plt.ylabel("GPA")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.regplot(x="sleep_hours", y="gpa", data=df)
plt.title("Regression: Sleep Hours vs GPA")
plt.show()

# %% [markdown]
# # 📊 Final Conclusion
#
# - Students sleeping around 7–8 hours tend to achieve better GPA.
# - Lower sleep duration is associated with higher stress levels.
# - Study hours positively influence GPA.
# - Maintaining proper sleep improves academic performance.
